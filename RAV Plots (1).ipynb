# %%
import xarray as xr
import numpy as np

# %%
rav=xr.open_dataset("/g/data/er4/dm1346/REALISED_ADDED_VALUES/realised_added_value_ensemble.nc")
rav
# Out:
# <xarray.Dataset>
# Dimensions:     (statistics: 7, lon: 841, lat: 681, model: 4)
# Coordinates:
#   * statistics  (statistics) object 'max' 'mean' 'min' ... 'pctl90' 'pctl95'
#   * lon         (lon) float64 112.0 112.0 112.1 112.2 ... 153.9 153.9 154.0
#   * lat         (lat) float64 -44.0 -43.95 -43.9 -43.85 ... -10.1 -10.05 -10.0
#     height      float64 ...
#   * model       (model) object 'GFDL-ESM2M' 'MIROC5' 'CNRM-CM5' 'ACCESS1-0'
# Data variables:
#     tasmax      (model, statistics, lat, lon) float32 ...
#     tasmin      (model, statistics, lat, lon) float32 ...
#     pr          (model, statistics, lat, lon) float32 ...

# %%
rav["tasmax"].sel(statistics="mean").plot(col="model",vmin=-10,vmax=10)

# %%
rav["tasmax"].sel(statistics="min").plot(col="model",vmin=-10,vmax=10)

# %%
rav["tasmax"].sel(statistics="max").plot(col="model",vmin=-10,vmax=10)

# %%
rav["tasmin"].sel(statistics="mean").plot(col="model",vmin=-10,vmax=10)

# %%
rav["tasmin"].sel(statistics="min").plot(col="model",vmin=-10,vmax=10)

# %%
rav["tasmin"].sel(statistics="max").plot(col="model",vmin=-10,vmax=10)

# %%
rav["pr"].sel(statistics="max").plot(col="model",vmin=-10,vmax=10)
